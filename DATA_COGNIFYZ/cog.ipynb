# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = 'Dataset_Cognifyz.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#    Restaurant_ID         Restaurant_Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.shape
# Out:
# (9551, 21)

# %%
data.dtypes
# Out:
# Restaurant_ID             int64
# Restaurant_Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality_Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average_Cost_for_two      int64
# Currency                 object
# Has_Table_booking        object
# Has_Online_delivery      object
# Is_delivering_now        object
# Switch_to_order_menu     object
# Price_range               int64
# Aggregate_rating        float64
# Rating_color             object
# Rating_text              object
# Votes                     int64
# dtype: object

# %%
data.dtypes.value_counts()
# Out:
# object     13
# int64       5
# float64     3
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant_ID         9551 non-null   int64
#  1   Restaurant_Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality_Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average_Cost_for_two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has_Table_booking     9551 non-null   object
#  13  Has_Online_delivery   9551 non-null   object
#  14  Is_delivering_now     9551 non-null   object
# ...

# %%
data['Cuisines'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Name: Cuisines, Length: 9551, dtype: bool

# %%
data.tail()
# Out:
#       Restaurant_ID           Restaurant_Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality_Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
pd.isnull(data['Cuisines']).sum()
# Out:
# np.int64(9)

# %%
data[data['Cuisines'].isnull()]
# Out:
#      Restaurant_ID                 Restaurant_Name  Country Code  \
# 84        17284105                   Cookie Shoppe           216
# 87        17284211  Pearly's Famous Country Cookng           216
# 94        17284158               Jimmie's Hot Dogs           216
# 297       17374552                  Corkscrew Cafe           216
# 328       17501439                        Dovetail           216
# 346       17606621            HI Lite Bar & Lounge           216
# 368       17059060                       Hillstone           216
# 418       17142698                Leonard's Bakery           216
# 455       17616465        Tybee Island Social Club           216
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Length: 9551, dtype: bool

# %%
data[data.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Restaurant_ID, Restaurant_Name, Country Code, City, Address, Locality, Locality_Verbose, Longitude, Latitude, Cuisines, Average_Cost_for_two, Currency, Has_Table_booking, Has_Online_delivery, Is_delivering_now, Switch_to_order_menu, Price_range, Aggregate_rating, Rating_color, Rating_text, Votes]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant_ID         9551 non-null   int64
#  1   Restaurant_Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality_Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average_Cost_for_two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has_Table_booking     9551 non-null   object
#  13  Has_Online_delivery   9551 non-null   object
#  14  Is_delivering_now     9551 non-null   object
# ...

# %%
data['Restaurant_ID'].unique()
# Out:
# array([6317637, 6304287, 6300002, ..., 5915807, 5916112, 5927402],
#       shape=(9551,))

# %%
data.head()
# Out:
#    Restaurant_ID         Restaurant_Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data['Average_Cost_for_two'].describe()
# Out:
# count      9551.000000
# mean       1199.210763
# std       16121.183073
# min           0.000000
# 25%         250.000000
# 50%         400.000000
# 75%         700.000000
# max      800000.000000
# Name: Average_Cost_for_two, dtype: float64

# %%
data[data['Average_Cost_for_two'] > 2000].count()
# Out:
# Restaurant_ID           258
# Restaurant_Name         258
# Country Code            258
# City                    258
# Address                 258
# Locality                258
# Locality_Verbose        258
# Longitude               258
# Latitude                258
# Cuisines                258
# Average_Cost_for_two    258
# Currency                258
# Has_Table_booking       258
# Has_Online_delivery     258
# Is_delivering_now       258
# Switch_to_order_menu    258
# Price_range             258
# Aggregate_rating        258
# Rating_color            258
# Rating_text             258
# Votes                   258
# dtype: int64

# %%
data['Price_range'].describe()
# Out:
# count    9551.000000
# mean        1.804837
# std         0.905609
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: Price_range, dtype: float64

# %%
data['Votes'].describe()
# Out:
# count     9551.000000
# mean       156.909748
# std        430.169145
# min          0.000000
# 25%          5.000000
# 50%         31.000000
# 75%        131.000000
# max      10934.000000
# Name: Votes, dtype: float64

# %%
data['Has_Online_delivery'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['Has_Table_booking'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['Is_delivering_now'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['Switch_to_order_menu'].unique()
# Out:
# array(['No'], dtype=object)

# %%
data['Aggregate_rating'].describe()
# Out:
# count    9551.000000
# mean        2.666370
# std         1.516378
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate_rating, dtype: float64

# %%
data[data['Aggregate_rating'] == 0].count()
# Out:
# Restaurant_ID           2148
# Restaurant_Name         2148
# Country Code            2148
# City                    2148
# Address                 2148
# Locality                2148
# Locality_Verbose        2148
# Longitude               2148
# Latitude                2148
# Cuisines                2148
# Average_Cost_for_two    2148
# Currency                2148
# Has_Table_booking       2148
# Has_Online_delivery     2148
# Is_delivering_now       2148
# Switch_to_order_menu    2148
# Price_range             2148
# Aggregate_rating        2148
# Rating_color            2148
# Rating_text             2148
# Votes                   2148
# dtype: int64

# %%
data['Rating_text'].value_counts()
# Out:
# Rating_text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
data[(data['Rating_text'] == 'Not rated') & (data['Aggregate_rating'] == 0)].count()
# Out:
# Restaurant_ID           2148
# Restaurant_Name         2148
# Country Code            2148
# City                    2148
# Address                 2148
# Locality                2148
# Locality_Verbose        2148
# Longitude               2148
# Latitude                2148
# Cuisines                2148
# Average_Cost_for_two    2148
# Currency                2148
# Has_Table_booking       2148
# Has_Online_delivery     2148
# Is_delivering_now       2148
# Switch_to_order_menu    2148
# Price_range             2148
# Aggregate_rating        2148
# Rating_color            2148
# Rating_text             2148
# Votes                   2148
# dtype: int64

# %%
data['Restaurant_Name'].unique()
# Out:
# array(['Le Petit Souffle', 'Izakaya Kikufuji', 'Heat - Edsa Shangri-La',
#        ..., 'Huqqa', 'A���k Kahve', "Walter's Coffee Roastery"],
#       shape=(7446,), dtype=object)

# %%
data[data['Restaurant_Name'].duplicated()].count()
# Out:
# Restaurant_ID           2105
# Restaurant_Name         2105
# Country Code            2105
# City                    2105
# Address                 2105
# Locality                2105
# Locality_Verbose        2105
# Longitude               2105
# Latitude                2105
# Cuisines                2105
# Average_Cost_for_two    2105
# Currency                2105
# Has_Table_booking       2105
# Has_Online_delivery     2105
# Is_delivering_now       2105
# Switch_to_order_menu    2105
# Price_range             2105
# Aggregate_rating        2105
# Rating_color            2105
# Rating_text             2105
# Votes                   2105
# dtype: int64

# %%
data[data['Cuisines'].duplicated()].count()
# Out:
# Restaurant_ID           7725
# Restaurant_Name         7725
# Country Code            7725
# City                    7725
# Address                 7725
# Locality                7725
# Locality_Verbose        7725
# Longitude               7725
# Latitude                7725
# Cuisines                7717
# Average_Cost_for_two    7725
# Currency                7725
# Has_Table_booking       7725
# Has_Online_delivery     7725
# Is_delivering_now       7725
# Switch_to_order_menu    7725
# Price_range             7725
# Aggregate_rating        7725
# Rating_color            7725
# Rating_text             7725
# Votes                   7725
# dtype: int64

# %%
data['Cuisines'].unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       shape=(1826,), dtype=object)

# %%
cuisines_counts = data['Cuisines'].str.split(', ').explode().value_counts()
cuisines_counts.shape
# Out:
# (145,)

# %%
cuisines_counts
# Out:
# Cuisines
# North Indian      3960
# Chinese           2735
# Fast Food         1986
# Mughlai            995
# Italian            764
#                   ...
# Cuisine Varies       1
# Fish and Chips       1
# Durban               1
# D�_ner               1
# B�_rek               1
# Name: count, Length: 145, dtype: int64

# %%
data[data.duplicated(subset=['Restaurant_Name'])]
# Out:
#       Restaurant_ID         Restaurant_Name  Country Code            City  \
# 12          6318433        Silantro Fil-Mex           162     Quezon City
# 39          6600427              Coco Bambu            30       Bras�_lia
# 61          7301700       Garota de Ipanema            30  Rio de Janeiro
# 140        17294836  Rhinehart's Oyster Bar           216         Augusta
# 202        17330309         Mellow Mushroom           216        Columbus
# ...             ...                     ...           ...             ...
# 9463        6516766            The National           189    Johannesburg
# 9490        6517568         Jamie's Italian           189         Sandton
# 9528        6003668             Timboo Cafe           208          Ankara
# 9535        6000921             D�_vero��lu           208          Ankara
# 9538        5901782               Starbucks           208       ��stanbul
#
#                                                 Address  \
# ...

# %%
percentage_of_restaurants_for_cuisines = cuisines_counts / len(data) * 100

# %%
percentage_of_restaurants_for_cuisines
# Out:
# Cuisines
# North Indian      41.461627
# Chinese           28.635745
# Fast Food         20.793634
# Mughlai           10.417757
# Italian            7.999162
#                     ...
# Cuisine Varies     0.010470
# Fish and Chips     0.010470
# Durban             0.010470
# D�_ner             0.010470
# B�_rek             0.010470
# Name: count, Length: 145, dtype: float64

# %%
restaurants_count = data['City'].value_counts()

# %%
restaurants_count
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lakes Entrance       1
# Mohali               1
# Panchkula            1
# Bandung              1
# Randburg             1
# Name: count, Length: 141, dtype: int64

# %%
data.groupby('City')['Aggregate_rating'].mean()
# Out:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ��stanbul          4.292857
# Name: Aggregate_rating, Length: 141, dtype: float64

# %%
data.groupby('City', as_index=False)['Aggregate_rating'].mean()
# Out:
#                 City  Aggregate_rating
# 0          Abu Dhabi          4.300000
# 1               Agra          3.965000
# 2          Ahmedabad          4.161905
# 3             Albany          3.555000
# 4          Allahabad          3.395000
# ..               ...               ...
# 136          Weirton          3.900000
# 137  Wellington City          4.250000
# 138   Winchester Bay          3.200000
# 139          Yorkton          3.300000
# 140        ��stanbul          4.292857
#
# [141 rows x 2 columns]

# %%
cities = data.groupby('City')['Aggregate_rating'].mean()

# %%
cities[cities > 4.5]
# Out:
# City
# Beechworth          4.600000
# Inner City          4.900000
# London              4.535000
# Makati City         4.650000
# Mandaluyong City    4.625000
# Pasig City          4.633333
# Quezon City         4.800000
# Taguig City         4.525000
# Name: Aggregate_rating, dtype: float64

# %%
cities[cities > 4.5].index
# Out:
# Index(['Beechworth', 'Inner City', 'London', 'Makati City', 'Mandaluyong City',
#        'Pasig City', 'Quezon City', 'Taguig City'],
#       dtype='object', name='City')

# %%
cities[cities > 4.5].index.tolist()
# Out:
# ['Beechworth',
#  'Inner City',
#  'London',
#  'Makati City',
#  'Mandaluyong City',
#  'Pasig City',
#  'Quezon City',
#  'Taguig City']

# %%
cities.index.max()
# Out:
# '��stanbul'

# %%
len(data[data['Has_Online_delivery'] == 'Yes'])/len(data) * 100
# Out:
# 25.662234321013504

# %%
len(data[data['Has_Online_delivery'] == 'No'])/len(data) * 100
# Out:
# 74.33776567898649

# %%
data[data['Has_Online_delivery'] == 'Yes'].count()
# Out:
# Restaurant_ID           2451
# Restaurant_Name         2451
# Country Code            2451
# City                    2451
# Address                 2451
# Locality                2451
# Locality_Verbose        2451
# Longitude               2451
# Latitude                2451
# Cuisines                2451
# Average_Cost_for_two    2451
# Currency                2451
# Has_Table_booking       2451
# Has_Online_delivery     2451
# Is_delivering_now       2451
# Switch_to_order_menu    2451
# Price_range             2451
# Aggregate_rating        2451
# Rating_color            2451
# Rating_text             2451
# Votes                   2451
# dtype: int64

# %%
data.groupby('Has_Online_delivery', as_index=False)['Aggregate_rating'].mean()
# Out:
#   Has_Online_delivery  Aggregate_rating
# 0                  No          2.465296
# 1                 Yes          3.248837

# %%
data['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian                          936
# North Indian, Chinese                 511
# Chinese                               354
# Fast Food                             354
# North Indian, Mughlai                 334
#                                      ...
# World Cuisine, Patisserie, Cafe         1
# Burger, Izgara                          1
# Desserts, B�_rek                        1
# Restaurant Cafe, Turkish, Desserts      1
# Restaurant Cafe, Desserts               1
# Name: count, Length: 1825, dtype: int64

# %%
data['Cuisines'].str.strip().str.lower()
# Out:
# 0             french, japanese, desserts
# 1                               japanese
# 2       seafood, asian, filipino, indian
# 3                        japanese, sushi
# 4                       japanese, korean
#                       ...
# 9546                             turkish
# 9547     world cuisine, patisserie, cafe
# 9548              italian, world cuisine
# 9549                     restaurant cafe
# 9550                                cafe
# Name: Cuisines, Length: 9551, dtype: object

# %%
sub = data['Cuisines'].apply(
    lambda x: len(str(x).split(',')) if pd.notnull(x) else 0
)

# %%
sub
# Out:
# 0       3
# 1       1
# 2       4
# 3       2
# 4       2
#        ..
# 9546    1
# 9547    3
# 9548    2
# 9549    1
# 9550    1
# Name: Cuisines, Length: 9551, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant_ID         9551 non-null   int64
#  1   Restaurant_Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality_Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average_Cost_for_two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has_Table_booking     9551 non-null   object
#  13  Has_Online_delivery   9551 non-null   object
#  14  Is_delivering_now     9551 non-null   object
# ...

# %%
cui = data['Cuisines'].dropna()
cui[cui.str.split(',').str.len() > 1].value_counts()
# Out:
# Cuisines
# North Indian, Chinese                         511
# North Indian, Mughlai                         334
# North Indian, Mughlai, Chinese                197
# Bakery, Desserts                              170
# Pizza, Fast Food                              131
#                                              ...
# Cafe, Sri Lankan, Continental, American         1
# Fast Food, French                               1
# American, Asian, Italian, Seafood               1
# Seafood, American, Mediterranean, Japanese      1
# European, South African, Steak                  1
# Name: count, Length: 1731, dtype: int64

# %%
cui[cui.str.split(',').str.len() > 1].count()
# Out:
# np.int64(6148)

# %%
dew = data[['Cuisines', 'Aggregate_rating']].dropna()
fog = dew[dew['Cuisines'].str.split(',').str.len() > 1]
wind = fog.groupby('Cuisines')['Aggregate_rating'].mean()
wind
# Out:
# Cuisines
# Afghani, Mughlai, Chinese                    0.0
# Afghani, North Indian                        0.0
# Afghani, North Indian, Pakistani, Arabian    0.0
# African, Portuguese                          4.2
# American, Asian, Burger                      4.6
#                                             ...
# Vietnamese, Fish and Chips                   4.3
# Western, Asian, Cafe                         4.2
# Western, Fusion, Fast Food                   3.2
# World Cuisine, Mexican, Italian              4.4
# World Cuisine, Patisserie, Cafe              4.2
# Name: Aggregate_rating, Length: 1731, dtype: float64

# %%
rain = fog['Aggregate_rating'].mean()
rain
# Out:
# np.float64(2.905139882888744)

# %%
tornado = dew[dew['Cuisines'].str.split(',').str.len()== 1]
snow = tornado['Aggregate_rating'].mean()
snow
# Out:
# np.float64(2.2306717737183264)

# %%
data['Rating_text'].value_counts().to_frame()
# Out:
#              count
# Rating_text
# Average       3737
# Not rated     2148
# Good          2100
# Very Good     1079
# Excellent      301
# Poor           186

# %%
data[data[['Votes']] > 0].count()
# Out:
# Restaurant_ID              0
# Restaurant_Name            0
# Country Code               0
# City                       0
# Address                    0
# Locality                   0
# Locality_Verbose           0
# Longitude                  0
# Latitude                   0
# Cuisines                   0
# Average_Cost_for_two       0
# Currency                   0
# Has_Table_booking          0
# Has_Online_delivery        0
# Is_delivering_now          0
# Switch_to_order_menu       0
# Price_range                0
# Aggregate_rating           0
# Rating_color               0
# Rating_text                0
# Votes                   8457
# dtype: int64

# %%
data.sort_values(by='Votes', ascending=False)
# Out:
#       Restaurant_ID                 Restaurant_Name  Country Code       City  \
# 728           51705                            Toit             1  Bangalore
# 735           51040                        Truffles             1  Bangalore
# 3994         308322                Hauz Khas Social             1  New Delhi
# 2412          20404                       Peter Cat             1    Kolkata
# 739           56618       AB's - Absolute Barbecues             1  Bangalore
# ...             ...                             ...           ...        ...
# 5732       18322599                     Daily Belly             1  New Delhi
# 5733           9226            Deep Bakery And Cake             1  New Delhi
# 5734       18434072                      Dhaba NH10             1  New Delhi
# 5735         305699                  Dilkhush Dhaba             1  New Delhi
# 5736           9194  Do Bhai Paneer Wale And Sweets             1  New Delhi
#
# ...

# %%
data['Aggregate_rating'].describe()
# Out:
# count    9551.000000
# mean        2.666370
# std         1.516378
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate_rating, dtype: float64
